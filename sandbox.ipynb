# %%
import pandas as pd
import math

# %%
fifa = pd.read_csv('fifa.csv')
pl = pd.read_json('pl.json').transpose()
ll = pd.read_csv('ll.csv')

# %%
df[(df['dob']=='1992-02-29') & (df['nationality']=="Brazil") & (df['club']=="Grêmio")]
# Out:
#       sofifa_id                                         player_url  \
# 235      230375  https://sofifa.com/player/230375/josue-durval-...
# 236      230481  https://sofifa.com/player/230481/ronaldo-jails...
# 2620     230324  https://sofifa.com/player/230324/adriano-leand...
# 2635     230503  https://sofifa.com/player/230503/matheus-jadso...
# 4711     230188  https://sofifa.com/player/230188/alam-cristian...
# 6579     230439  https://sofifa.com/player/230439/roldao-tony-r...
#
#             short_name                        long_name  age         dob  \
# 235   Josué Chiamulera      Josué Durval Chiamulera Vaz   27  1992-02-29
# 236    Ronaldo Cabrais    Ronaldo Jailson Cabrais Petri   27  1992-02-29
# 2620      Adrianiscito  Adriano Leandro Soares Taffarel   27  1992-02-29
# 2635    Jadson Vidigal    Matheus Jadson Vidigal Morais   27  1992-02-29
# 4711       Alam Araújo     Alam Cristian Araújo Martins   27  1992-02-29
# ...

# %%
df[df.duplicated(['dob', 'nationality', 'club'])]
# Out:
#        sofifa_id                                         player_url  \
# 236       230481  https://sofifa.com/player/230481/ronaldo-jails...
# 328       245313  https://sofifa.com/player/245313/jose-maria-si...
# 409       245305  https://sofifa.com/player/245305/luis-roberto-...
# 515       177458  https://sofifa.com/player/177458/sven-bender/2...
# 565       245294  https://sofifa.com/player/245294/jorge-ezequie...
# ...          ...                                                ...
# 17148     243348  https://sofifa.com/player/243348/lukas-klitten...
# 17165     252608  https://sofifa.com/player/252608/kyung-hyun-mi...
# 17179     244075  https://sofifa.com/player/244075/nick-otto/20/...
# 17567     239773  https://sofifa.com/player/239773/alex-reid/20/...
# 17895     247317  https://sofifa.com/player/247317/jose-orlando-...
#
#             short_name                      long_name  age         dob  \
# 236    Ronaldo Cabrais  Ronaldo Jailson Cabrais Petri   27  1992-02-29
# ...

# %%
# Out:
# Series([], Name: short_name, dtype: object)

# %%
types = ['Normal', 'Lean', 'Stocky']
df[~df.body_type.isin(types)][['long_name', 'body_type']].head(11)
# Out:
#                                  long_name            body_type
# 0           Lionel Andrés Messi Cuccittini                Messi
# 1      Cristiano Ronaldo dos Santos Aveiro           C. Ronaldo
# 2            Neymar da Silva Santos Junior               Neymar
# 9                     Mohamed  Salah Ghaly  PLAYER_BODY_TYPE_25
# 28                        Thibaut Courtois             Courtois
# 313                        Xherdan Shaqiri              Shaqiri
# 10693                    Adebayo Akinfenwa            Akinfenwa

# %%
for col in ll.columns: 
    print(col)
# Out:
# Team
# Position
# Shirt number
# Name
# Minutes played
# Games played
# Percentage of games played
# Full games played
# Percentage of full games played
# Games started
# Percentage of games started
# Games where substituted
# Percentage of games where substituted
# Yellow Cards
# Red Cards
# Second Yellows
# Goals scored
# Penalties scored
# Own goals
# Goals conceded while player on pitch
# Tackles
# Interceptions
# Recoveries
# Clearances
# Successful tackles
# Unssuccessful tackles
# Last man
# Successful duels
# Duels lost
# Successful aerial challenges
# Unsuccessful aerial challenges
# Offsides
# Fouls suffered
# Fouls committed
# Penalties won
# Penalties given away
# Handballs committed
# Fouls committed per card
# Shots
# Shots on target
# Assists
# Successful dribbles
# Unsuccessful dribbles
# Goals scored.1
# From inside the area
# From outside the area
# Goals with left foot
# Goals with right foot
# Penalties scored.1
# Goals scored with header
# Goals from set piece
# ...

# %%
for col in pl.columns: 
    print(col)
# Out:
# Club
# Position
# Appearances
# Goals
# Wins
# Losses
# Attack
# Goals Per Match
# Goals With Header
# Goals With Right Foot
# Goals With Left Foot
# Penalties Scored
# Goals From Freekick
# Shots
# Shots On Target
# Shooting Accuracy %
# Hit Woodwork
# Big Chances Missed
# Team Play
# Assists
# Passes
# Passes Per Match
# Big Chances Created
# Crosses
# Cross Accuracy %
# Through Balls
# Accurate Long Balls
# Discipline
# Yellow Cards
# Red Cards
# Fouls
# Offsides
# Defence
# Tackles
# Tackle Success %
# Blocked Shots
# Interceptions
# Clearances
# Headed Clearance
# Recoveries
# Duels Won
# Duels Lost
# Successful 50/50s
# Aerial Battles Won
# Aerial Battles Lost
# Errors Leading To Goal
# Goals per match
# Headed goals
# Goals with right foot
# Goals with left foot
# Penalties scored
# Freekicks scored
# Shots on target
# Shooting accuracy %
# Hit woodwork
# Big chances missed
# Passes per match
# Big chances created
# Yellow cards
# Red cards
# Blocked shots
# Clean sheets
# ...
